# %%
import pydot
from IPython.display import Image
import cheerios
reload(cheerios)
from cheerios import CheerioCodec as CC
import pmf
reload(pmf)
from pmf import PMFArray as PMF
from BitVector import BitVector as BV

# %%
pmf = PMF()
pmf.count('a')
pmf.count('b')
pmf.frame()
# Out:
#    freq    p
# a     1  0.5
# b     1  0.5
#
# [2 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('c')
pmf.count('d')
pmf.frame()
# Out:
#    freq     p
# a     1  0.25
# b     1  0.25
# c     1  0.25
# d     1  0.25
#
# [4 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('e')
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('a',4)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# True

# %%
pmf.count('f',3)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# False

# %%
pmf.frame()
# Out:
#    freq         p
# a     5  0.416667
# b     1  0.083333
# c     1  0.083333
# d     1  0.083333
# e     1  0.083333
# f     3  0.250000
#
# [6 rows x 2 columns]

# %%
cc.pmf().frame()
# Out:
#        freq         p
# a  0.416667  0.416667
# b  0.083333  0.083333
# f  0.250000  0.250000
# c  0.083333  0.083333
# e  0.083333  0.083333
# d  0.083333  0.083333
#
# [6 rows x 2 columns]

# %%
print cc.information(), cc.pmf().entropy()
# Out:
# 1.75 2.221251836

# %%
[ (s, str(bv)) for (s,bv) in cc.lookup.items() ]
# Out:
# [('a', '0'), ('c', '11'), ('b', '01'), ('e', '110'), ('d', '111'), ('f', '10')]

# %%
from random import randint
pmf = PMF()
for i in xrange(100) :
    pmf.count(chr(ord('a') + randint(0,25)))
pmf.frame()
# Out:
#    freq     p
# m     5  0.05
# k     6  0.06
# j     6  0.06
# n     2  0.02
# x     2  0.02
# q     4  0.04
# y     4  0.04
# d     5  0.05
# f     5  0.05
# e     7  0.07
# o     6  0.06
# h     4  0.04
# c     4  0.04
# p     4  0.04
# t     4  0.04
# g     5  0.05
# w     4  0.04
# v     1  0.01
# l     4  0.04
# s     2  0.02
# i     4  0.04
# b     3  0.03
# u     3  0.03
# z     4  0.04
# a     2  0.02
#
# [25 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
cc.pmf().frame()
# Out:
#    freq     p
# a  0.02  0.02
# s  0.02  0.02
# b  0.03  0.03
# d  0.05  0.05
# t  0.04  0.04
# e  0.07  0.07
# i  0.04  0.04
# c  0.04  0.04
# g  0.05  0.05
# y  0.04  0.04
# j  0.06  0.06
# p  0.04  0.04
# h  0.04  0.04
# m  0.05  0.05
# z  0.04  0.04
# o  0.06  0.06
# q  0.04  0.04
# n  0.02  0.02
# v  0.01  0.01
# u  0.03  0.03
# w  0.04  0.04
# f  0.05  0.05
# k  0.06  0.06
# l  0.04  0.04
# x  0.02  0.02
#
# [25 rows x 2 columns]

# %%
hp = pmf.entropy()
hc = cc.information()
print hp, hc, hc / hp
# Out:
# 4.54256472608 3.35 0.737468853392

# %%
bits = BV(textstring="hello")
str(bits)
# Out:
# '0110100001100101011011000110110001101111'

# %%
es = ''.join(cc.encode(bits)[0])
es
# Out:
# 'jgthyjjseqtqx'

# %%
db = cc.decode(es)
print(repr(str(db)))
db[:len(bits)] == bits
# Out:
# '0110100001100101011011000110110001101111111'
# True

# %%
cc.encode(bits,1)
# Out:
# (['c'], 2)
