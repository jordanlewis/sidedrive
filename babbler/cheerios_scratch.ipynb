# %%
import pydot
from IPython.display import Image
import cheerios
reload(cheerios)
from cheerios import CheerioCodec as CC
import pmf
reload(pmf)
from pmf import PMFArray as PMF

# %%
pmf = PMF()
pmf.count('a')
pmf.count('b')
pmf.frame()
# Out:
#    freq    p
# a     1  0.5
# b     1  0.5
#
# [2 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('c')
pmf.count('d')
pmf.frame()
# Out:
#    freq     p
# a     1  0.25
# b     1  0.25
# c     1  0.25
# d     1  0.25
#
# [4 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('e')
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('a',4)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# True

# %%
pmf.count('f',3)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# False

# %%
pmf.frame()
# Out:
#    freq         p
# a     5  0.416667
# b     1  0.083333
# c     1  0.083333
# d     1  0.083333
# e     1  0.083333
# f     3  0.250000
#
# [6 rows x 2 columns]

# %%
cc.pmf().frame()
# Out:
#        freq         p
# a  0.416667  0.416667
# b  0.083333  0.083333
# f  0.250000  0.250000
# c  0.083333  0.083333
# e  0.083333  0.083333
# d  0.083333  0.083333
#
# [6 rows x 2 columns]

# %%
print cc.information(), cc.pmf().entropy()
# Out:
# 1.75 2.221251836

# %%
[ (s, str(bv)) for (s,bv) in cc.lookup.items() ]
# Out:
# [('a', '0'), ('c', '11'), ('b', '01'), ('e', '110'), ('d', '111'), ('f', '10')]

# %%
from random import randint
pmf = PMF()
for i in xrange(100) :
    pmf.count(chr(ord('a') + randint(0,15)))
pmf.frame()
# Out:
#    freq     p
# p     7  0.07
# k     9  0.09
# n     9  0.09
# l    10  0.10
# o     6  0.06
# j     5  0.05
# b     5  0.05
# c     5  0.05
# e     4  0.04
# g     8  0.08
# d     5  0.05
# h     9  0.09
# m     3  0.03
# i     8  0.08
# f     2  0.02
# a     5  0.05
#
# [16 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
cc.pmf().frame()
# Out:
#    freq     p
# a  0.05  0.05
# j  0.05  0.05
# o  0.06  0.06
# l  0.10  0.10
# c  0.05  0.05
# g  0.08  0.08
# h  0.09  0.09
# f  0.02  0.02
# e  0.04  0.04
# d  0.05  0.05
# p  0.07  0.07
# k  0.09  0.09
# b  0.05  0.05
# i  0.08  0.08
# n  0.09  0.09
# m  0.03  0.03
#
# [16 rows x 2 columns]

# %%
hp = pmf.entropy()
hc = cc.information()
print hp, hc, hc / hp
# Out:
# 3.89614013657 2.67 0.685293625592
