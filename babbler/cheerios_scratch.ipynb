# %%
import pydot
from IPython.display import Image
import cheerios
reload(cheerios)
from cheerios import CheerioCodec as CC
import pmf
reload(pmf)
from pmf import PMFArray as PMF
from BitVector import BitVector as BV

# %%
pmf = PMF()
pmf.count('a')
pmf.count('b')
pmf.frame()
# Out:
#    freq    p
# a     1  0.5
# b     1  0.5
#
# [2 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('c')
pmf.count('d')
pmf.frame()
# Out:
#    freq     p
# a     1  0.25
# b     1  0.25
# c     1  0.25
# d     1  0.25
#
# [4 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('e')
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
pmf.count('a',4)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# True

# %%
pmf.count('f',3)
cc = CC(pmf)
print cc.is_degenerate()
g = cc.graph()
Image(g.create_png())
# Out:
# False

# %%
pmf.frame()
# Out:
#    freq         p
# a     5  0.416667
# b     1  0.083333
# c     1  0.083333
# d     1  0.083333
# e     1  0.083333
# f     3  0.250000
#
# [6 rows x 2 columns]

# %%
cc.pmf().frame()
# Out:
#        freq         p
# a  0.416667  0.416667
# b  0.083333  0.083333
# f  0.250000  0.250000
# c  0.083333  0.083333
# e  0.083333  0.083333
# d  0.083333  0.083333
#
# [6 rows x 2 columns]

# %%
print cc.information(), cc.pmf().entropy()
# Out:
# 1.75 2.221251836

# %%
[ (s, str(bv)) for (s,bv) in cc.lookup.items() ]
# Out:
# [('a', '0'), ('c', '11'), ('b', '01'), ('e', '110'), ('d', '111'), ('f', '10')]

# %%
from random import randint
pmf = PMF()
for i in xrange(100) :
    pmf.count(chr(ord('a') + randint(0,25)))
pmf.frame()
# Out:
#    freq     p
# y     6  0.06
# h     5  0.05
# t     5  0.05
# f     8  0.08
# s     2  0.02
# j     8  0.08
# q     1  0.01
# n     4  0.04
# r     2  0.02
# e     4  0.04
# m     4  0.04
# w     6  0.06
# l     6  0.06
# o     4  0.04
# p     6  0.06
# b     4  0.04
# u     4  0.04
# x     4  0.04
# z     2  0.02
# c     3  0.03
# d     2  0.02
# v     2  0.02
# k     1  0.01
# i     1  0.01
# a     5  0.05
# g     1  0.01
#
# [26 rows x 2 columns]

# %%
cc = CC(pmf)
g = cc.graph()
Image(g.create_png())

# %%
cc.pmf().frame()
# Out:
#    freq     p
# i  0.01  0.01
# j  0.08  0.08
# b  0.04  0.04
# t  0.05  0.05
# q  0.01  0.01
# o  0.04  0.04
# v  0.02  0.02
# r  0.02  0.02
# y  0.06  0.06
# a  0.05  0.05
# p  0.06  0.06
# m  0.04  0.04
# z  0.02  0.02
# d  0.02  0.02
# s  0.02  0.02
# u  0.04  0.04
# h  0.05  0.05
# f  0.08  0.08
# e  0.04  0.04
# c  0.03  0.03
# w  0.06  0.06
# x  0.04  0.04
# l  0.06  0.06
# n  0.04  0.04
# k  0.01  0.01
# g  0.01  0.01
#
# [26 rows x 2 columns]

# %%
hp = pmf.entropy()
hc = cc.information()
print hp, hc, hc / hp
# Out:
# 4.48762710035 3.63 0.808890738653

# %%
bits = BV(textstring="hello")
str(bits)
# Out:
# '0110100001100101011011000110110001101111'

# %%
es = ''.join(cc.encode(bits))
es
# Out:
# 'pupyepopoz'

# %%
db = cc.decode(es)
print(repr(str(db)))
db == bits
# Out:
# '0110100001100101011011000110110001101111'
# True
